# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanthi17/Recognizing-human-values-in-arguments/blob/main/Human_Values_in_Arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Identifying the human values behind arguments

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd 'gdrive/MyDrive/Colab Notebooks/NLP/Final Project'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/NLP/Final Project

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 17.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 78.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 54.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertModel
from torch.utils.data import DataLoader, Dataset, TensorDataset
from torch.autograd import Variable
import numpy as np
from sklearn.metrics import f1_score

# %% [markdown]
# ## Load Level-2 data from the Human Values Dataset
# Train data and Validation data is loaded seperately from the given tsv files

# %%
df_train_args = pd.read_csv("final-data/arguments-training.tsv", encoding='utf-8', sep='\t')
df_train_labels = pd.read_csv("final-data/labels-training.tsv", encoding='utf-8', sep='\t')

df_train = pd.merge(df_train_args, df_train_labels, on='Argument ID')

# %%
df_valid_args = pd.read_csv("final-data/arguments-validation.tsv", encoding='utf-8', sep='\t')
df_valid_labels = pd.read_csv("final-data/labels-validation.tsv", encoding='utf-8', sep='\t')

df_valid = pd.merge(df_valid_args, df_valid_labels, on='Argument ID')

# %%
df_train.shape, df_valid.shape
# Out:
# ((5393, 24), (1896, 24))

# %% [markdown]
# ## Load BERT tokenizer to calculate the maximum length of sentences

# %%
# # Load the BERT tokenizer

# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# bert_model = BertModel.from_pretrained("bert-base-uncased")
# if torch.cuda.is_available():
#     bert_model = bert_model.to('cuda')

# %%
# max_len = 0

# for sent in conclusion_text:
#     input_ids = tokenizer.encode(sent, add_special_tokens=True)
#     max_len = max(max_len, len(input_ids))

# print('Max sentence length: ', max_len)

# %% [markdown]
# # Creating textual representations

# %% [markdown]
# 1. Load the BERT base uncased tokenizer
# 2. Load BERT base uncased model
# 3. Create Dataset class for Dataloader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
bert_model = BertModel.from_pretrained("bert-base-uncased").to(device)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## Creating textual representation of the data
# 1. Create textual representation of Conclusion with BERT tokenizer and BERT model.
# 2. Create textual representation for Premise just like Conclusion
# 3. Stance has only two inputs: 'in favor of' or 'against'. So, it is given binary representation

# %%
class MyDataset(Dataset):
    def __init__(self,df_data,device=device, tokenizer=tokenizer, bert_model=bert_model):
        self.conclusion = df_data['Conclusion'].values
        self.stance = df_data['Stance'].values
        self.premise = df_data['Premise'].values
        self.y = df_data.iloc[:,4:].values
        self.device = device
        self.tokenizer = tokenizer
        self.bert_model = bert_model

    def __len__(self):
        return len(self.y)

    def __getitem__(self,idx):
        conclusion = self.bert_model(**self.tokenizer(self.conclusion[idx], max_length=32, padding='max_length', truncation=True, return_tensors='pt').to(self.device)).pooler_output
        premise = self.bert_model(**self.tokenizer(self.premise[idx], max_length=128, padding='max_length', truncation=True, return_tensors='pt').to(self.device)).pooler_output
        stance = torch.Tensor([1] if self.stance[idx] == 'in favor of' else [0])[:, None]
        return torch.cat([conclusion.to(self.device), stance.to(self.device), premise.to(self.device)], axis=1), torch.Tensor(self.y[idx]).to(self.device)

# %% [markdown]
# ## Save representations to file
# Create Dataset object for the data and use it in DataLoader for batch wise dataloading. The final representations are saved to numpy file

# %%
train_dataset = MyDataset(df_train)
valid_dataset = MyDataset(df_valid)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=8)
valid_dataloader = DataLoader(valid_dataset, batch_size=8)

# %%
x = []
y = []

for batch in valid_dataloader:
    data, label = batch
    x.append(data.detach().cpu().numpy())
    y.append(label.detach().cpu().numpy())

# %%
# np.save('final-data/train_data.npy', np.concatenate(x))
# np.save('final-data/train_label.npy', np.concatenate(y))

np.save('final-data/valid_data.npy', np.concatenate(x))
np.save('final-data/valid_label.npy', np.concatenate(y))

# %% [markdown]
# # Load the Data
#
# The dataset is imbalanced when each individual label is used to train the model. So, before training the binary classifier we balance the dataset

# %%
import os
from keras.models import Sequential, load_model
from keras.layers import Dropout, Dense, LSTM, GRU, RNN
from keras.utils import to_categorical

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score
from keras.optimizers import SGD

# %%
train_data = np.load('final-data/train_data.npy')
train_label = np.load('final-data/train_label.npy')

# %%
valid_data = np.load('final-data/valid_data.npy')
valid_label = np.load('final-data/valid_label.npy')

# %%
# Returns balanced dataset for given label
def get_data(data, label, label_number):

    # Get the indices where ones and zeros are there in the label array
    one_indices = np.where(label[:,label_number]==1)[0]
    zero_indices = np.where(label[:,label_number]==0)[0]

    # Get min of the two, to get the size of each class in balanced dataset
    size = min(len(one_indices), len(zero_indices))

    # Create balanced data and label using the indices
    balanced_data = np.concatenate((data[one_indices[:size]], data[zero_indices[:size]]))
    balanced_label = np.concatenate((label[one_indices[:size]], label[zero_indices[:size]]))

    return balanced_data, balanced_label[:, label_number].astype('float32').reshape((-1,1))

# %% [markdown]
# # Train the model
# Created 20 different classifiers to classify each label seperately. Each classifier is trained on different label data and are combined together at the end. The ensemble of these 20 models will return the prediction for a data point

# %%
# Optimizer
sgd = SGD(learning_rate=0.00001, momentum=0.8, nesterov=True)

# %%
def get_model():
    # Return the binary classifier 
    model = Sequential()
    model.add(LSTM(300, input_shape = (1, 1537)))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

    return model

# %%
batch_size=128
n_epochs = 30
models = []
histories = []

# Running in a loop to train 20 different binary classifiers
for i in range(20):
    x_train, y_train = get_data(train_data, train_label, i)
    x_val, y_val =  get_data(valid_data, valid_label, i)
    print("--------------------------------------------------------------------------------------------")
    print(x_train.shape)
    print("--------------------------------------------------------------------------------------------")
    model = get_model()

    # Added checkpoints and early stopping regularization
    early_stop = EarlyStopping(monitor='val_loss', patience=5)
    fpath = "Models/model_binary_{}.h5".format(i+1)
    checkpoint = ModelCheckpoint(filepath=fpath, monitor="val_loss",
                                verbose=1, 
                                save_best_only=True,
                                mode="min")
    callbacks = [checkpoint,early_stop]

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=n_epochs, validation_data=(x_val, y_val), callbacks=callbacks)

    histories.append(history)
    models.append(model)
# Out:
# --------------------------------------------------------------------------------------------
# (1976, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
#  9/16 [===============>..............] - ETA: 0s - loss: 0.7038 - accuracy: 0.5026
# Epoch 1: val_loss improved from inf to 0.70143, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 4s 91ms/step - loss: 0.7045 - accuracy: 0.5000 - val_loss: 0.7014 - val_accuracy: 0.5000
# Epoch 2/30
# 13/16 [=======================>......] - ETA: 0s - loss: 0.7056 - accuracy: 0.4958
# Epoch 2: val_loss improved from 0.70143 to 0.70118, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7042 - accuracy: 0.5000 - val_loss: 0.7012 - val_accuracy: 0.5000
# Epoch 3/30
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7036 - accuracy: 0.5010
# Epoch 3: val_loss improved from 0.70118 to 0.70094, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.7038 - accuracy: 0.5000 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 4/30
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7033 - accuracy: 0.5006
# Epoch 4: val_loss improved from 0.70094 to 0.70072, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.7035 - accuracy: 0.5000 - val_loss: 0.7007 - val_accuracy: 0.5000
# Epoch 5/30
# 16/16 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.5000
# Epoch 5: val_loss improved from 0.70072 to 0.70049, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 26ms/step - loss: 0.7032 - accuracy: 0.5000 - val_loss: 0.7005 - val_accuracy: 0.5000
# Epoch 6/30
#  8/16 [==============>...............] - ETA: 0s - loss: 0.7062 - accuracy: 0.4922
# Epoch 6: val_loss improved from 0.70049 to 0.70027, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 20ms/step - loss: 0.7029 - accuracy: 0.5000 - val_loss: 0.7003 - val_accuracy: 0.5000
# Epoch 7/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6995 - accuracy: 0.5092
# Epoch 7: val_loss improved from 0.70027 to 0.70006, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.7026 - accuracy: 0.5000 - val_loss: 0.7001 - val_accuracy: 0.5000
# Epoch 8/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.7009 - accuracy: 0.5057
# Epoch 8: val_loss improved from 0.70006 to 0.69985, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.7024 - accuracy: 0.5000 - val_loss: 0.6999 - val_accuracy: 0.5000
# Epoch 9/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.7003 - accuracy: 0.5057
# Epoch 9: val_loss improved from 0.69985 to 0.69964, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 40ms/step - loss: 0.7021 - accuracy: 0.5000 - val_loss: 0.6996 - val_accuracy: 0.5000
# Epoch 10/30
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7029 - accuracy: 0.4961
# Epoch 10: val_loss improved from 0.69964 to 0.69944, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 43ms/step - loss: 0.7018 - accuracy: 0.5000 - val_loss: 0.6994 - val_accuracy: 0.5000
# Epoch 11/30
# 13/16 [=======================>......] - ETA: 0s - loss: 0.7016 - accuracy: 0.4994
# Epoch 11: val_loss improved from 0.69944 to 0.69926, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 40ms/step - loss: 0.7016 - accuracy: 0.5000 - val_loss: 0.6993 - val_accuracy: 0.5000
# Epoch 12/30
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7020 - accuracy: 0.4972
# Epoch 12: val_loss improved from 0.69926 to 0.69907, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 38ms/step - loss: 0.7013 - accuracy: 0.5000 - val_loss: 0.6991 - val_accuracy: 0.5000
# Epoch 13/30
# 16/16 [==============================] - ETA: 0s - loss: 0.7011 - accuracy: 0.5000
# Epoch 13: val_loss improved from 0.69907 to 0.69889, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.7011 - accuracy: 0.5000 - val_loss: 0.6989 - val_accuracy: 0.5000
# Epoch 14/30
# 12/16 [=====================>........] - ETA: 0s - loss: 0.7010 - accuracy: 0.4993
# Epoch 14: val_loss improved from 0.69889 to 0.69871, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 42ms/step - loss: 0.7008 - accuracy: 0.5000 - val_loss: 0.6987 - val_accuracy: 0.5000
# Epoch 15/30
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7007 - accuracy: 0.4995
# Epoch 15: val_loss improved from 0.69871 to 0.69854, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 36ms/step - loss: 0.7006 - accuracy: 0.5000 - val_loss: 0.6985 - val_accuracy: 0.5000
# Epoch 16/30
# 16/16 [==============================] - ETA: 0s - loss: 0.7003 - accuracy: 0.5000
# Epoch 16: val_loss improved from 0.69854 to 0.69839, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 49ms/step - loss: 0.7003 - accuracy: 0.5000 - val_loss: 0.6984 - val_accuracy: 0.5000
# Epoch 17/30
# 16/16 [==============================] - ETA: 0s - loss: 0.7001 - accuracy: 0.5000
# Epoch 17: val_loss improved from 0.69839 to 0.69823, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 32ms/step - loss: 0.7001 - accuracy: 0.5000 - val_loss: 0.6982 - val_accuracy: 0.5000
# Epoch 18/30
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6999 - accuracy: 0.5006
# Epoch 18: val_loss improved from 0.69823 to 0.69807, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.6999 - accuracy: 0.5000 - val_loss: 0.6981 - val_accuracy: 0.5000
# Epoch 19/30
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6999 - accuracy: 0.4995
# Epoch 19: val_loss improved from 0.69807 to 0.69792, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.6997 - accuracy: 0.5000 - val_loss: 0.6979 - val_accuracy: 0.5000
# Epoch 20/30
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6994 - accuracy: 0.5006
# Epoch 20: val_loss improved from 0.69792 to 0.69777, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 45ms/step - loss: 0.6995 - accuracy: 0.5000 - val_loss: 0.6978 - val_accuracy: 0.5000
# Epoch 21/30
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6994 - accuracy: 0.4995
# Epoch 21: val_loss improved from 0.69777 to 0.69763, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 46ms/step - loss: 0.6993 - accuracy: 0.5000 - val_loss: 0.6976 - val_accuracy: 0.5000
# Epoch 22/30
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6984 - accuracy: 0.5031
# Epoch 22: val_loss improved from 0.69763 to 0.69750, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 1s 39ms/step - loss: 0.6991 - accuracy: 0.5000 - val_loss: 0.6975 - val_accuracy: 0.5000
# Epoch 23/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.7003 - accuracy: 0.4950
# Epoch 23: val_loss improved from 0.69750 to 0.69735, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6989 - accuracy: 0.5000 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 24/30
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6979 - accuracy: 0.5026
# Epoch 24: val_loss improved from 0.69735 to 0.69722, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 19ms/step - loss: 0.6987 - accuracy: 0.5000 - val_loss: 0.6972 - val_accuracy: 0.5000
# Epoch 25/30
# 10/16 [=================>............] - ETA: 0s - loss: 0.6994 - accuracy: 0.4969
# Epoch 25: val_loss improved from 0.69722 to 0.69709, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6985 - accuracy: 0.5000 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 26/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6991 - accuracy: 0.4964
# Epoch 26: val_loss improved from 0.69709 to 0.69697, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.6984 - accuracy: 0.5000 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 27/30
# 11/16 [===================>..........] - ETA: 0s - loss: 0.6996 - accuracy: 0.4943
# Epoch 27: val_loss improved from 0.69697 to 0.69686, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6982 - accuracy: 0.5000 - val_loss: 0.6969 - val_accuracy: 0.5000
# Epoch 28/30
# 10/16 [=================>............] - ETA: 0s - loss: 0.6969 - accuracy: 0.5063
# Epoch 28: val_loss improved from 0.69686 to 0.69675, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.6980 - accuracy: 0.5000 - val_loss: 0.6967 - val_accuracy: 0.5000
# Epoch 29/30
#  9/16 [===============>..............] - ETA: 0s - loss: 0.6969 - accuracy: 0.5061
# Epoch 29: val_loss improved from 0.69675 to 0.69662, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.6979 - accuracy: 0.5000 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 30/30
# 10/16 [=================>............] - ETA: 0s - loss: 0.6949 - accuracy: 0.5133
# Epoch 30: val_loss improved from 0.69662 to 0.69651, saving model to Models/model_binary_1.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.6977 - accuracy: 0.5000 - val_loss: 0.6965 - val_accuracy: 0.5000
# --------------------------------------------------------------------------------------------
# (2790, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6964 - accuracy: 0.5004
# Epoch 1: val_loss improved from inf to 0.69647, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 3s 63ms/step - loss: 0.6963 - accuracy: 0.5004 - val_loss: 0.6965 - val_accuracy: 0.4990
# Epoch 2/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6966 - accuracy: 0.4978
# Epoch 2: val_loss improved from 0.69647 to 0.69643, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6963 - accuracy: 0.5004 - val_loss: 0.6964 - val_accuracy: 0.4990
# Epoch 3/30
# 18/22 [=======================>......] - ETA: 0s - loss: 0.6962 - accuracy: 0.5009
# Epoch 3: val_loss improved from 0.69643 to 0.69638, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.6962 - accuracy: 0.5004 - val_loss: 0.6964 - val_accuracy: 0.4990
# Epoch 4/30
# 18/22 [=======================>......] - ETA: 0s - loss: 0.6958 - accuracy: 0.5035
# Epoch 4: val_loss improved from 0.69638 to 0.69633, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 17ms/step - loss: 0.6962 - accuracy: 0.5004 - val_loss: 0.6963 - val_accuracy: 0.4990
# Epoch 5/30
# 19/22 [========================>.....] - ETA: 0s - loss: 0.6969 - accuracy: 0.4951
# Epoch 5: val_loss improved from 0.69633 to 0.69628, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6962 - accuracy: 0.5004 - val_loss: 0.6963 - val_accuracy: 0.4990
# Epoch 6/30
# 19/22 [========================>.....] - ETA: 0s - loss: 0.6966 - accuracy: 0.4955
# Epoch 6: val_loss improved from 0.69628 to 0.69623, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6961 - accuracy: 0.5004 - val_loss: 0.6962 - val_accuracy: 0.4990
# Epoch 7/30
# 18/22 [=======================>......] - ETA: 0s - loss: 0.6958 - accuracy: 0.5030
# Epoch 7: val_loss improved from 0.69623 to 0.69619, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6961 - accuracy: 0.5004 - val_loss: 0.6962 - val_accuracy: 0.4990
# Epoch 8/30
# 16/22 [====================>.........] - ETA: 0s - loss: 0.6970 - accuracy: 0.4946
# Epoch 8: val_loss improved from 0.69619 to 0.69614, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 0.6960 - accuracy: 0.5004 - val_loss: 0.6961 - val_accuracy: 0.4990
# Epoch 9/30
# 14/22 [==================>...........] - ETA: 0s - loss: 0.6961 - accuracy: 0.4989
# Epoch 9: val_loss improved from 0.69614 to 0.69610, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6960 - accuracy: 0.5004 - val_loss: 0.6961 - val_accuracy: 0.4990
# Epoch 10/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6958 - accuracy: 0.5011
# Epoch 10: val_loss improved from 0.69610 to 0.69606, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6959 - accuracy: 0.5004 - val_loss: 0.6961 - val_accuracy: 0.4990
# Epoch 11/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6959 - accuracy: 0.5004
# Epoch 11: val_loss improved from 0.69606 to 0.69601, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6959 - accuracy: 0.5004 - val_loss: 0.6960 - val_accuracy: 0.4990
# Epoch 12/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6958 - accuracy: 0.5011
# Epoch 12: val_loss improved from 0.69601 to 0.69597, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6958 - accuracy: 0.5004 - val_loss: 0.6960 - val_accuracy: 0.4990
# Epoch 13/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6956 - accuracy: 0.5015
# Epoch 13: val_loss improved from 0.69597 to 0.69593, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6958 - accuracy: 0.5004 - val_loss: 0.6959 - val_accuracy: 0.4990
# Epoch 14/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6958 - accuracy: 0.5004
# Epoch 14: val_loss improved from 0.69593 to 0.69588, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6958 - accuracy: 0.5004 - val_loss: 0.6959 - val_accuracy: 0.4990
# Epoch 15/30
# 22/22 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.5004
# Epoch 15: val_loss improved from 0.69588 to 0.69584, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6957 - accuracy: 0.5004 - val_loss: 0.6958 - val_accuracy: 0.4990
# Epoch 16/30
# 20/22 [==========================>...] - ETA: 0s - loss: 0.6962 - accuracy: 0.4961
# Epoch 16: val_loss improved from 0.69584 to 0.69580, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6957 - accuracy: 0.5004 - val_loss: 0.6958 - val_accuracy: 0.4990
# Epoch 17/30
# 20/22 [==========================>...] - ETA: 0s - loss: 0.6953 - accuracy: 0.5023
# Epoch 17: val_loss improved from 0.69580 to 0.69576, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6956 - accuracy: 0.5004 - val_loss: 0.6958 - val_accuracy: 0.4990
# Epoch 18/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6955 - accuracy: 0.5007
# Epoch 18: val_loss improved from 0.69576 to 0.69572, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6956 - accuracy: 0.5004 - val_loss: 0.6957 - val_accuracy: 0.4990
# Epoch 19/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6955 - accuracy: 0.5004
# Epoch 19: val_loss improved from 0.69572 to 0.69568, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6955 - accuracy: 0.5004 - val_loss: 0.6957 - val_accuracy: 0.4990
# Epoch 20/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6955 - accuracy: 0.5000
# Epoch 20: val_loss improved from 0.69568 to 0.69564, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6955 - accuracy: 0.5004 - val_loss: 0.6956 - val_accuracy: 0.4990
# Epoch 21/30
# 18/22 [=======================>......] - ETA: 0s - loss: 0.6950 - accuracy: 0.5048
# Epoch 21: val_loss improved from 0.69564 to 0.69560, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6955 - accuracy: 0.5004 - val_loss: 0.6956 - val_accuracy: 0.4990
# Epoch 22/30
# 20/22 [==========================>...] - ETA: 0s - loss: 0.6959 - accuracy: 0.4957
# Epoch 22: val_loss improved from 0.69560 to 0.69556, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6954 - accuracy: 0.5004 - val_loss: 0.6956 - val_accuracy: 0.4990
# Epoch 23/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6952 - accuracy: 0.5019
# Epoch 23: val_loss improved from 0.69556 to 0.69553, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6954 - accuracy: 0.5004 - val_loss: 0.6955 - val_accuracy: 0.4990
# Epoch 24/30
# 20/22 [==========================>...] - ETA: 0s - loss: 0.6951 - accuracy: 0.5027
# Epoch 24: val_loss improved from 0.69553 to 0.69549, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 19ms/step - loss: 0.6954 - accuracy: 0.5004 - val_loss: 0.6955 - val_accuracy: 0.4990
# Epoch 25/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6957 - accuracy: 0.4970
# Epoch 25: val_loss improved from 0.69549 to 0.69545, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6953 - accuracy: 0.5004 - val_loss: 0.6955 - val_accuracy: 0.4990
# Epoch 26/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6953 - accuracy: 0.4993
# Epoch 26: val_loss improved from 0.69545 to 0.69542, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6953 - accuracy: 0.5004 - val_loss: 0.6954 - val_accuracy: 0.4990
# Epoch 27/30
# 19/22 [========================>.....] - ETA: 0s - loss: 0.6962 - accuracy: 0.4926
# Epoch 27: val_loss improved from 0.69542 to 0.69538, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 18ms/step - loss: 0.6953 - accuracy: 0.5004 - val_loss: 0.6954 - val_accuracy: 0.4990
# Epoch 28/30
# 20/22 [==========================>...] - ETA: 0s - loss: 0.6957 - accuracy: 0.4957
# Epoch 28: val_loss improved from 0.69538 to 0.69535, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6952 - accuracy: 0.5004 - val_loss: 0.6953 - val_accuracy: 0.4990
# Epoch 29/30
# 19/22 [========================>.....] - ETA: 0s - loss: 0.6964 - accuracy: 0.4905
# Epoch 29: val_loss improved from 0.69535 to 0.69531, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6952 - accuracy: 0.5004 - val_loss: 0.6953 - val_accuracy: 0.4990
# Epoch 30/30
# 21/22 [===========================>..] - ETA: 0s - loss: 0.6953 - accuracy: 0.4996
# Epoch 30: val_loss improved from 0.69531 to 0.69528, saving model to Models/model_binary_2.h5
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6951 - accuracy: 0.5004 - val_loss: 0.6953 - val_accuracy: 0.4990
# --------------------------------------------------------------------------------------------
# (494, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 1/4 [======>.......................] - ETA: 4s - loss: 0.6927 - accuracy: 0.4922
# Epoch 1: val_loss improved from inf to 0.69408, saving model to Models/model_binary_3.h5
# 4/4 [==============================] - 3s 402ms/step - loss: 0.6935 - accuracy: 0.4777 - val_loss: 0.6941 - val_accuracy: 0.4819
# Epoch 2/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6944 - accuracy: 0.4531
# Epoch 2: val_loss did not improve from 0.69408
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6935 - accuracy: 0.4777 - val_loss: 0.6941 - val_accuracy: 0.4819
# Epoch 3/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6921 - accuracy: 0.4766
# Epoch 3: val_loss did not improve from 0.69408
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6935 - accuracy: 0.4777 - val_loss: 0.6941 - val_accuracy: 0.4819
# Epoch 4/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6934 - accuracy: 0.5000
# Epoch 4: val_loss did not improve from 0.69408
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6935 - accuracy: 0.4757 - val_loss: 0.6941 - val_accuracy: 0.4819
# Epoch 5/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6951 - accuracy: 0.4609
# Epoch 5: val_loss did not improve from 0.69408
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6935 - accuracy: 0.4757 - val_loss: 0.6941 - val_accuracy: 0.4819
# Epoch 6/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6944 - accuracy: 0.4766
# Epoch 6: val_loss did not improve from 0.69408
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6935 - accuracy: 0.4757 - val_loss: 0.6941 - val_accuracy: 0.4819
# --------------------------------------------------------------------------------------------
# (344, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 1/3 [=========>....................] - ETA: 3s - loss: 0.7133 - accuracy: 0.4531
# Epoch 1: val_loss improved from inf to 0.71827, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 3s 819ms/step - loss: 0.7059 - accuracy: 0.4942 - val_loss: 0.7183 - val_accuracy: 0.5000
# Epoch 2/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7036 - accuracy: 0.4922
# Epoch 2: val_loss improved from 0.71827 to 0.71826, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 126ms/step - loss: 0.7059 - accuracy: 0.4942 - val_loss: 0.7183 - val_accuracy: 0.5000
# Epoch 3/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7095 - accuracy: 0.4844
# Epoch 3: val_loss improved from 0.71826 to 0.71823, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 152ms/step - loss: 0.7059 - accuracy: 0.4942 - val_loss: 0.7182 - val_accuracy: 0.5000
# Epoch 4/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7067 - accuracy: 0.4766
# Epoch 4: val_loss improved from 0.71823 to 0.71821, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 142ms/step - loss: 0.7059 - accuracy: 0.4942 - val_loss: 0.7182 - val_accuracy: 0.5000
# Epoch 5/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7157 - accuracy: 0.4531
# Epoch 5: val_loss improved from 0.71821 to 0.71818, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 224ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7182 - val_accuracy: 0.5000
# Epoch 6/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7094 - accuracy: 0.4609
# Epoch 6: val_loss improved from 0.71818 to 0.71815, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 150ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7182 - val_accuracy: 0.5000
# Epoch 7/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7146 - accuracy: 0.4688
# Epoch 7: val_loss improved from 0.71815 to 0.71813, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 220ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7181 - val_accuracy: 0.5000
# Epoch 8/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7057 - accuracy: 0.5000
# Epoch 8: val_loss improved from 0.71813 to 0.71810, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 160ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7181 - val_accuracy: 0.5000
# Epoch 9/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7129 - accuracy: 0.4688
# Epoch 9: val_loss improved from 0.71810 to 0.71808, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 146ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7181 - val_accuracy: 0.5000
# Epoch 10/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7167 - accuracy: 0.4375
# Epoch 10: val_loss improved from 0.71808 to 0.71805, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 139ms/step - loss: 0.7058 - accuracy: 0.4942 - val_loss: 0.7180 - val_accuracy: 0.5000
# Epoch 11/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6990 - accuracy: 0.5156
# Epoch 11: val_loss improved from 0.71805 to 0.71802, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 142ms/step - loss: 0.7057 - accuracy: 0.4942 - val_loss: 0.7180 - val_accuracy: 0.5000
# Epoch 12/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7113 - accuracy: 0.4609
# Epoch 12: val_loss improved from 0.71802 to 0.71800, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7057 - accuracy: 0.4942 - val_loss: 0.7180 - val_accuracy: 0.5000
# Epoch 13/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7073 - accuracy: 0.5000
# Epoch 13: val_loss improved from 0.71800 to 0.71797, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 139ms/step - loss: 0.7057 - accuracy: 0.4942 - val_loss: 0.7180 - val_accuracy: 0.5000
# Epoch 14/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6947 - accuracy: 0.5391
# Epoch 14: val_loss improved from 0.71797 to 0.71794, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 151ms/step - loss: 0.7057 - accuracy: 0.4942 - val_loss: 0.7179 - val_accuracy: 0.5000
# Epoch 15/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7130 - accuracy: 0.4531
# Epoch 15: val_loss improved from 0.71794 to 0.71791, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 133ms/step - loss: 0.7057 - accuracy: 0.4942 - val_loss: 0.7179 - val_accuracy: 0.5000
# Epoch 16/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7027 - accuracy: 0.5234
# Epoch 16: val_loss improved from 0.71791 to 0.71789, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 145ms/step - loss: 0.7056 - accuracy: 0.4942 - val_loss: 0.7179 - val_accuracy: 0.5000
# Epoch 17/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7032 - accuracy: 0.5078
# Epoch 17: val_loss improved from 0.71789 to 0.71786, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 197ms/step - loss: 0.7056 - accuracy: 0.4942 - val_loss: 0.7179 - val_accuracy: 0.5000
# Epoch 18/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7168 - accuracy: 0.4375
# Epoch 18: val_loss improved from 0.71786 to 0.71783, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7056 - accuracy: 0.4971 - val_loss: 0.7178 - val_accuracy: 0.5000
# Epoch 19/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7091 - accuracy: 0.4766
# Epoch 19: val_loss improved from 0.71783 to 0.71780, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 140ms/step - loss: 0.7056 - accuracy: 0.4971 - val_loss: 0.7178 - val_accuracy: 0.5000
# Epoch 20/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6915 - accuracy: 0.5859
# Epoch 20: val_loss improved from 0.71780 to 0.71778, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 154ms/step - loss: 0.7056 - accuracy: 0.4971 - val_loss: 0.7178 - val_accuracy: 0.5000
# Epoch 21/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7084 - accuracy: 0.4844
# Epoch 21: val_loss improved from 0.71778 to 0.71775, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 140ms/step - loss: 0.7056 - accuracy: 0.4971 - val_loss: 0.7178 - val_accuracy: 0.5000
# Epoch 22/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7097 - accuracy: 0.4844
# Epoch 22: val_loss improved from 0.71775 to 0.71772, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 133ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7177 - val_accuracy: 0.5000
# Epoch 23/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7240 - accuracy: 0.4219
# Epoch 23: val_loss improved from 0.71772 to 0.71770, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 146ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7177 - val_accuracy: 0.4951
# Epoch 24/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6938 - accuracy: 0.5156
# Epoch 24: val_loss improved from 0.71770 to 0.71767, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 141ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7177 - val_accuracy: 0.4951
# Epoch 25/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7076 - accuracy: 0.4766
# Epoch 25: val_loss improved from 0.71767 to 0.71765, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 145ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7176 - val_accuracy: 0.4951
# Epoch 26/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7026 - accuracy: 0.5234
# Epoch 26: val_loss improved from 0.71765 to 0.71763, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 141ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7176 - val_accuracy: 0.4951
# Epoch 27/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7057 - accuracy: 0.4766
# Epoch 27: val_loss improved from 0.71763 to 0.71760, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7055 - accuracy: 0.4971 - val_loss: 0.7176 - val_accuracy: 0.4951
# Epoch 28/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7071 - accuracy: 0.5000
# Epoch 28: val_loss improved from 0.71760 to 0.71757, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 145ms/step - loss: 0.7054 - accuracy: 0.5000 - val_loss: 0.7176 - val_accuracy: 0.4951
# Epoch 29/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6994 - accuracy: 0.5078
# Epoch 29: val_loss improved from 0.71757 to 0.71755, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 143ms/step - loss: 0.7054 - accuracy: 0.5000 - val_loss: 0.7175 - val_accuracy: 0.4951
# Epoch 30/30
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7045 - accuracy: 0.5391
# Epoch 30: val_loss improved from 0.71755 to 0.71752, saving model to Models/model_binary_4.h5
# 3/3 [==============================] - 0s 134ms/step - loss: 0.7054 - accuracy: 0.5000 - val_loss: 0.7175 - val_accuracy: 0.4951
# --------------------------------------------------------------------------------------------
# (3024, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 21/24 [=========================>....] - ETA: 0s - loss: 0.6952 - accuracy: 0.5030
# Epoch 1: val_loss improved from inf to 0.69596, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 3s 76ms/step - loss: 0.6953 - accuracy: 0.5013 - val_loss: 0.6960 - val_accuracy: 0.5000
# Epoch 2/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6944 - accuracy: 0.5074
# Epoch 2: val_loss improved from 0.69596 to 0.69591, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6952 - accuracy: 0.5017 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 3/30
# 21/24 [=========================>....] - ETA: 0s - loss: 0.6948 - accuracy: 0.5048
# Epoch 3: val_loss improved from 0.69591 to 0.69586, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 19ms/step - loss: 0.6952 - accuracy: 0.5017 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 4/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6949 - accuracy: 0.5017
# Epoch 4: val_loss improved from 0.69586 to 0.69581, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6951 - accuracy: 0.5020 - val_loss: 0.6958 - val_accuracy: 0.4991
# Epoch 5/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6939 - accuracy: 0.5132
# Epoch 5: val_loss improved from 0.69581 to 0.69576, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6951 - accuracy: 0.5017 - val_loss: 0.6958 - val_accuracy: 0.4991
# Epoch 6/30
# 21/24 [=========================>....] - ETA: 0s - loss: 0.6953 - accuracy: 0.4989
# Epoch 6: val_loss improved from 0.69576 to 0.69570, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 32ms/step - loss: 0.6950 - accuracy: 0.5020 - val_loss: 0.6957 - val_accuracy: 0.4991
# Epoch 7/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6955 - accuracy: 0.4971
# Epoch 7: val_loss improved from 0.69570 to 0.69566, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 19ms/step - loss: 0.6949 - accuracy: 0.5030 - val_loss: 0.6957 - val_accuracy: 0.5000
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.5030
# Epoch 8: val_loss improved from 0.69566 to 0.69561, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6949 - accuracy: 0.5030 - val_loss: 0.6956 - val_accuracy: 0.5000
# Epoch 9/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6957 - accuracy: 0.4996
# Epoch 9: val_loss improved from 0.69561 to 0.69556, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6949 - accuracy: 0.5036 - val_loss: 0.6956 - val_accuracy: 0.5000
# Epoch 10/30
# 21/24 [=========================>....] - ETA: 0s - loss: 0.6944 - accuracy: 0.5048
# Epoch 10: val_loss improved from 0.69556 to 0.69552, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6948 - accuracy: 0.5036 - val_loss: 0.6955 - val_accuracy: 0.5000
# Epoch 11/30
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6947 - accuracy: 0.5044
# Epoch 11: val_loss improved from 0.69552 to 0.69548, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6948 - accuracy: 0.5036 - val_loss: 0.6955 - val_accuracy: 0.4991
# Epoch 12/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6946 - accuracy: 0.5066
# Epoch 12: val_loss improved from 0.69548 to 0.69543, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6947 - accuracy: 0.5033 - val_loss: 0.6954 - val_accuracy: 0.4983
# Epoch 13/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6937 - accuracy: 0.5122
# Epoch 13: val_loss improved from 0.69543 to 0.69540, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6947 - accuracy: 0.5043 - val_loss: 0.6954 - val_accuracy: 0.4983
# Epoch 14/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6943 - accuracy: 0.5062
# Epoch 14: val_loss improved from 0.69540 to 0.69535, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6946 - accuracy: 0.5046 - val_loss: 0.6954 - val_accuracy: 0.4983
# Epoch 15/30
# 20/24 [========================>.....] - ETA: 0s - loss: 0.6950 - accuracy: 0.5016
# Epoch 15: val_loss improved from 0.69535 to 0.69531, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6946 - accuracy: 0.5043 - val_loss: 0.6953 - val_accuracy: 0.4974
# Epoch 16/30
# 20/24 [========================>.....] - ETA: 0s - loss: 0.6939 - accuracy: 0.5090
# Epoch 16: val_loss improved from 0.69531 to 0.69527, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6945 - accuracy: 0.5043 - val_loss: 0.6953 - val_accuracy: 0.4983
# Epoch 17/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6949 - accuracy: 0.5012
# Epoch 17: val_loss improved from 0.69527 to 0.69523, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6945 - accuracy: 0.5043 - val_loss: 0.6952 - val_accuracy: 0.4991
# Epoch 18/30
# 20/24 [========================>.....] - ETA: 0s - loss: 0.6950 - accuracy: 0.5008
# Epoch 18: val_loss improved from 0.69523 to 0.69519, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6945 - accuracy: 0.5046 - val_loss: 0.6952 - val_accuracy: 0.4991
# Epoch 19/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6947 - accuracy: 0.5021
# Epoch 19: val_loss improved from 0.69519 to 0.69516, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6944 - accuracy: 0.5043 - val_loss: 0.6952 - val_accuracy: 0.4991
# Epoch 20/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6939 - accuracy: 0.5087
# Epoch 20: val_loss improved from 0.69516 to 0.69512, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6944 - accuracy: 0.5046 - val_loss: 0.6951 - val_accuracy: 0.4991
# Epoch 21/30
# 21/24 [=========================>....] - ETA: 0s - loss: 0.6942 - accuracy: 0.5060
# Epoch 21: val_loss improved from 0.69512 to 0.69509, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6944 - accuracy: 0.5050 - val_loss: 0.6951 - val_accuracy: 0.4991
# Epoch 22/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6938 - accuracy: 0.5074
# Epoch 22: val_loss improved from 0.69509 to 0.69505, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6943 - accuracy: 0.5053 - val_loss: 0.6951 - val_accuracy: 0.4983
# Epoch 23/30
# 20/24 [========================>.....] - ETA: 0s - loss: 0.6939 - accuracy: 0.5098
# Epoch 23: val_loss improved from 0.69505 to 0.69502, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6943 - accuracy: 0.5056 - val_loss: 0.6950 - val_accuracy: 0.4991
# Epoch 24/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6944 - accuracy: 0.5030
# Epoch 24: val_loss improved from 0.69502 to 0.69498, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6942 - accuracy: 0.5060 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 25/30
# 17/24 [====================>.........] - ETA: 0s - loss: 0.6945 - accuracy: 0.5032
# Epoch 25: val_loss improved from 0.69498 to 0.69495, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 31ms/step - loss: 0.6942 - accuracy: 0.5073 - val_loss: 0.6949 - val_accuracy: 0.4991
# Epoch 26/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6939 - accuracy: 0.5103
# Epoch 26: val_loss improved from 0.69495 to 0.69492, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 19ms/step - loss: 0.6942 - accuracy: 0.5079 - val_loss: 0.6949 - val_accuracy: 0.4991
# Epoch 27/30
# 19/24 [======================>.......] - ETA: 0s - loss: 0.6944 - accuracy: 0.5070
# Epoch 27: val_loss improved from 0.69492 to 0.69489, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 21ms/step - loss: 0.6941 - accuracy: 0.5089 - val_loss: 0.6949 - val_accuracy: 0.4974
# Epoch 28/30
# 24/24 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.5089
# Epoch 28: val_loss improved from 0.69489 to 0.69486, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6941 - accuracy: 0.5089 - val_loss: 0.6949 - val_accuracy: 0.4974
# Epoch 29/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6936 - accuracy: 0.5148
# Epoch 29: val_loss improved from 0.69486 to 0.69483, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6941 - accuracy: 0.5093 - val_loss: 0.6948 - val_accuracy: 0.4991
# Epoch 30/30
# 18/24 [=====================>........] - ETA: 0s - loss: 0.6943 - accuracy: 0.5043
# Epoch 30: val_loss improved from 0.69483 to 0.69480, saving model to Models/model_binary_5.h5
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6941 - accuracy: 0.5096 - val_loss: 0.6948 - val_accuracy: 0.5000
# --------------------------------------------------------------------------------------------
# (1220, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5057
# Epoch 1: val_loss improved from inf to 0.69599, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 4s 212ms/step - loss: 0.6939 - accuracy: 0.5057 - val_loss: 0.6960 - val_accuracy: 0.4756
# Epoch 2/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6938 - accuracy: 0.5043
# Epoch 2: val_loss improved from 0.69599 to 0.69596, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 48ms/step - loss: 0.6939 - accuracy: 0.5057 - val_loss: 0.6960 - val_accuracy: 0.4787
# Epoch 3/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6940 - accuracy: 0.5009
# Epoch 3: val_loss improved from 0.69596 to 0.69594, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 48ms/step - loss: 0.6938 - accuracy: 0.5016 - val_loss: 0.6959 - val_accuracy: 0.4787
# Epoch 4/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6966 - accuracy: 0.5000
# Epoch 4: val_loss improved from 0.69594 to 0.69591, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 47ms/step - loss: 0.6938 - accuracy: 0.5049 - val_loss: 0.6959 - val_accuracy: 0.4787
# Epoch 5/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6941 - accuracy: 0.5035
# Epoch 5: val_loss improved from 0.69591 to 0.69589, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 47ms/step - loss: 0.6938 - accuracy: 0.5066 - val_loss: 0.6959 - val_accuracy: 0.4817
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5082
# Epoch 6: val_loss improved from 0.69589 to 0.69586, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6938 - accuracy: 0.5082 - val_loss: 0.6959 - val_accuracy: 0.4817
# Epoch 7/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6951 - accuracy: 0.4609
# Epoch 7: val_loss improved from 0.69586 to 0.69584, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6937 - accuracy: 0.5098 - val_loss: 0.6958 - val_accuracy: 0.4817
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5090
# Epoch 8: val_loss improved from 0.69584 to 0.69581, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 48ms/step - loss: 0.6937 - accuracy: 0.5090 - val_loss: 0.6958 - val_accuracy: 0.4817
# Epoch 9/30
#  8/10 [=======================>......] - ETA: 0s - loss: 0.6938 - accuracy: 0.5098
# Epoch 9: val_loss improved from 0.69581 to 0.69579, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 46ms/step - loss: 0.6937 - accuracy: 0.5082 - val_loss: 0.6958 - val_accuracy: 0.4817
# Epoch 10/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6936 - accuracy: 0.5069
# Epoch 10: val_loss improved from 0.69579 to 0.69577, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6936 - accuracy: 0.5090 - val_loss: 0.6958 - val_accuracy: 0.4817
# Epoch 11/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6940 - accuracy: 0.5087
# Epoch 11: val_loss improved from 0.69577 to 0.69574, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6936 - accuracy: 0.5098 - val_loss: 0.6957 - val_accuracy: 0.4817
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5082
# Epoch 12: val_loss improved from 0.69574 to 0.69572, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6936 - accuracy: 0.5082 - val_loss: 0.6957 - val_accuracy: 0.4848
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5090
# Epoch 13: val_loss improved from 0.69572 to 0.69569, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 50ms/step - loss: 0.6936 - accuracy: 0.5090 - val_loss: 0.6957 - val_accuracy: 0.4848
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5115
# Epoch 14: val_loss improved from 0.69569 to 0.69567, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6935 - accuracy: 0.5115 - val_loss: 0.6957 - val_accuracy: 0.4848
# Epoch 15/30
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6938 - accuracy: 0.5089
# Epoch 15: val_loss improved from 0.69567 to 0.69564, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 54ms/step - loss: 0.6935 - accuracy: 0.5123 - val_loss: 0.6956 - val_accuracy: 0.4817
# Epoch 16/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6951 - accuracy: 0.4922
# Epoch 16: val_loss improved from 0.69564 to 0.69561, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6935 - accuracy: 0.5107 - val_loss: 0.6956 - val_accuracy: 0.4817
# Epoch 17/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6901 - accuracy: 0.5781
# Epoch 17: val_loss improved from 0.69561 to 0.69559, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6934 - accuracy: 0.5123 - val_loss: 0.6956 - val_accuracy: 0.4817
# Epoch 18/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6934 - accuracy: 0.5139
# Epoch 18: val_loss improved from 0.69559 to 0.69556, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6934 - accuracy: 0.5115 - val_loss: 0.6956 - val_accuracy: 0.4848
# Epoch 19/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6947 - accuracy: 0.5156
# Epoch 19: val_loss improved from 0.69556 to 0.69554, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6934 - accuracy: 0.5107 - val_loss: 0.6955 - val_accuracy: 0.4848
# Epoch 20/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6935 - accuracy: 0.5104
# Epoch 20: val_loss improved from 0.69554 to 0.69552, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6934 - accuracy: 0.5115 - val_loss: 0.6955 - val_accuracy: 0.4848
# Epoch 21/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6935 - accuracy: 0.5069
# Epoch 21: val_loss improved from 0.69552 to 0.69549, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6933 - accuracy: 0.5098 - val_loss: 0.6955 - val_accuracy: 0.4848
# Epoch 22/30
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6935 - accuracy: 0.5078
# Epoch 22: val_loss improved from 0.69549 to 0.69546, saving model to Models/model_binary_6.h5
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6933 - accuracy: 0.5115 - val_loss: 0.6955 - val_accuracy: 0.4848
# Epoch 23/30
# ...
# 11/11 [==============================] - 1s 88ms/step - loss: 0.6927 - accuracy: 0.4955 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 12/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6932 - accuracy: 0.4912
# Epoch 12: val_loss improved from 0.69421 to 0.69420, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 89ms/step - loss: 0.6926 - accuracy: 0.4955 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 13/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6919 - accuracy: 0.5029
# Epoch 13: val_loss improved from 0.69420 to 0.69419, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 97ms/step - loss: 0.6926 - accuracy: 0.4962 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 14/30
#  7/11 [==================>...........] - ETA: 0s - loss: 0.6927 - accuracy: 0.4967
# Epoch 14: val_loss improved from 0.69419 to 0.69418, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 93ms/step - loss: 0.6926 - accuracy: 0.4955 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 15/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6928 - accuracy: 0.4951
# Epoch 15: val_loss improved from 0.69418 to 0.69417, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 90ms/step - loss: 0.6926 - accuracy: 0.4970 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 16/30
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6923 - accuracy: 0.4974
# Epoch 16: val_loss improved from 0.69417 to 0.69417, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 93ms/step - loss: 0.6926 - accuracy: 0.4970 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 17/30
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6927 - accuracy: 0.4969
# Epoch 17: val_loss improved from 0.69417 to 0.69416, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 104ms/step - loss: 0.6926 - accuracy: 0.4970 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 18/30
#  7/11 [==================>...........] - ETA: 0s - loss: 0.6926 - accuracy: 0.4944
# Epoch 18: val_loss improved from 0.69416 to 0.69415, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 92ms/step - loss: 0.6926 - accuracy: 0.4977 - val_loss: 0.6942 - val_accuracy: 0.4955
# Epoch 19/30
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6926 - accuracy: 0.4983
# Epoch 19: val_loss improved from 0.69415 to 0.69414, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 89ms/step - loss: 0.6926 - accuracy: 0.4985 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 20/30
#  6/11 [===============>..............] - ETA: 0s - loss: 0.6934 - accuracy: 0.5013
# Epoch 20: val_loss improved from 0.69414 to 0.69414, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 92ms/step - loss: 0.6925 - accuracy: 0.4985 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 21/30
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6922 - accuracy: 0.4991
# Epoch 21: val_loss improved from 0.69414 to 0.69413, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 88ms/step - loss: 0.6925 - accuracy: 0.4985 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 22/30
#  7/11 [==================>...........] - ETA: 0s - loss: 0.6926 - accuracy: 0.4900
# Epoch 22: val_loss improved from 0.69413 to 0.69412, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 103ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 23/30
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6924 - accuracy: 0.5016
# Epoch 23: val_loss improved from 0.69412 to 0.69411, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 99ms/step - loss: 0.6925 - accuracy: 0.5008 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 24/30
#  7/11 [==================>...........] - ETA: 0s - loss: 0.6920 - accuracy: 0.5056
# Epoch 24: val_loss improved from 0.69411 to 0.69410, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 93ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 25/30
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.4939
# Epoch 25: val_loss improved from 0.69410 to 0.69409, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 94ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 26/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6930 - accuracy: 0.4912
# Epoch 26: val_loss improved from 0.69409 to 0.69409, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 93ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 27/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6925 - accuracy: 0.4961
# Epoch 27: val_loss improved from 0.69409 to 0.69408, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6924 - accuracy: 0.5015 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 28/30
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6924 - accuracy: 0.5039
# Epoch 28: val_loss improved from 0.69408 to 0.69407, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 93ms/step - loss: 0.6924 - accuracy: 0.5030 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 29/30
#  9/11 [=======================>......] - ETA: 0s - loss: 0.6924 - accuracy: 0.5087
# Epoch 29: val_loss improved from 0.69407 to 0.69406, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 94ms/step - loss: 0.6924 - accuracy: 0.5045 - val_loss: 0.6941 - val_accuracy: 0.4955
# Epoch 30/30
#  8/11 [====================>.........] - ETA: 0s - loss: 0.6929 - accuracy: 0.5029
# Epoch 30: val_loss improved from 0.69406 to 0.69405, saving model to Models/model_binary_19.h5
# 11/11 [==============================] - 1s 97ms/step - loss: 0.6924 - accuracy: 0.5045 - val_loss: 0.6941 - val_accuracy: 0.4955
# --------------------------------------------------------------------------------------------
# (2108, 1, 1537)
# --------------------------------------------------------------------------------------------
# Epoch 1/30
# 10/17 [================>.............] - ETA: 0s - loss: 0.6959 - accuracy: 0.5063
# Epoch 1: val_loss improved from inf to 0.69543, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 4s 137ms/step - loss: 0.6965 - accuracy: 0.4957 - val_loss: 0.6954 - val_accuracy: 0.4919
# Epoch 2/30
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6967 - accuracy: 0.4927
# Epoch 2: val_loss improved from 0.69543 to 0.69538, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 69ms/step - loss: 0.6964 - accuracy: 0.4957 - val_loss: 0.6954 - val_accuracy: 0.4906
# Epoch 3/30
# 12/17 [====================>.........] - ETA: 0s - loss: 0.6957 - accuracy: 0.5033
# Epoch 3: val_loss improved from 0.69538 to 0.69534, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6963 - accuracy: 0.4953 - val_loss: 0.6953 - val_accuracy: 0.4919
# Epoch 4/30
# 17/17 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.4934
# Epoch 4: val_loss improved from 0.69534 to 0.69529, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6962 - accuracy: 0.4934 - val_loss: 0.6953 - val_accuracy: 0.4906
# Epoch 5/30
#  9/17 [==============>...............] - ETA: 0s - loss: 0.6949 - accuracy: 0.5165
# Epoch 5: val_loss improved from 0.69529 to 0.69524, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6962 - accuracy: 0.4934 - val_loss: 0.6952 - val_accuracy: 0.4919
# Epoch 6/30
# 14/17 [=======================>......] - ETA: 0s - loss: 0.6959 - accuracy: 0.4961
# Epoch 6: val_loss improved from 0.69524 to 0.69519, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6961 - accuracy: 0.4929 - val_loss: 0.6952 - val_accuracy: 0.4973
# Epoch 7/30
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6959 - accuracy: 0.4912
# Epoch 7: val_loss improved from 0.69519 to 0.69514, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 70ms/step - loss: 0.6960 - accuracy: 0.4886 - val_loss: 0.6951 - val_accuracy: 0.4933
# Epoch 8/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6960 - accuracy: 0.4880
# Epoch 8: val_loss improved from 0.69514 to 0.69509, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6959 - accuracy: 0.4877 - val_loss: 0.6951 - val_accuracy: 0.4973
# Epoch 9/30
# 13/17 [=====================>........] - ETA: 0s - loss: 0.6957 - accuracy: 0.4856
# Epoch 9: val_loss improved from 0.69509 to 0.69505, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6958 - accuracy: 0.4867 - val_loss: 0.6950 - val_accuracy: 0.4973
# Epoch 10/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6962 - accuracy: 0.4833
# Epoch 10: val_loss improved from 0.69505 to 0.69500, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 68ms/step - loss: 0.6958 - accuracy: 0.4862 - val_loss: 0.6950 - val_accuracy: 0.4946
# Epoch 11/30
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6955 - accuracy: 0.4897
# Epoch 11: val_loss improved from 0.69500 to 0.69497, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6957 - accuracy: 0.4872 - val_loss: 0.6950 - val_accuracy: 0.4946
# Epoch 12/30
# 17/17 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.4858
# Epoch 12: val_loss improved from 0.69497 to 0.69492, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.6956 - accuracy: 0.4858 - val_loss: 0.6949 - val_accuracy: 0.4933
# Epoch 13/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6956 - accuracy: 0.4865
# Epoch 13: val_loss improved from 0.69492 to 0.69488, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.6956 - accuracy: 0.4862 - val_loss: 0.6949 - val_accuracy: 0.4933
# Epoch 14/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6962 - accuracy: 0.4807
# Epoch 14: val_loss improved from 0.69488 to 0.69484, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 65ms/step - loss: 0.6955 - accuracy: 0.4872 - val_loss: 0.6948 - val_accuracy: 0.4906
# Epoch 15/30
# 14/17 [=======================>......] - ETA: 0s - loss: 0.6956 - accuracy: 0.4872
# Epoch 15: val_loss improved from 0.69484 to 0.69481, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6955 - accuracy: 0.4886 - val_loss: 0.6948 - val_accuracy: 0.4838
# Epoch 16/30
# 10/17 [================>.............] - ETA: 0s - loss: 0.6957 - accuracy: 0.4875
# Epoch 16: val_loss improved from 0.69481 to 0.69478, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6954 - accuracy: 0.4867 - val_loss: 0.6948 - val_accuracy: 0.4825
# Epoch 17/30
# 14/17 [=======================>......] - ETA: 0s - loss: 0.6952 - accuracy: 0.4872
# Epoch 17: val_loss improved from 0.69478 to 0.69475, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.6953 - accuracy: 0.4862 - val_loss: 0.6948 - val_accuracy: 0.4825
# Epoch 18/30
# 10/17 [================>.............] - ETA: 0s - loss: 0.6965 - accuracy: 0.4820
# Epoch 18: val_loss improved from 0.69475 to 0.69472, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.6953 - accuracy: 0.4862 - val_loss: 0.6947 - val_accuracy: 0.4798
# Epoch 19/30
# 14/17 [=======================>......] - ETA: 0s - loss: 0.6948 - accuracy: 0.4883
# Epoch 19: val_loss improved from 0.69472 to 0.69469, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6952 - accuracy: 0.4848 - val_loss: 0.6947 - val_accuracy: 0.4784
# Epoch 20/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6948 - accuracy: 0.4927
# Epoch 20: val_loss improved from 0.69469 to 0.69465, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6952 - accuracy: 0.4843 - val_loss: 0.6947 - val_accuracy: 0.4784
# Epoch 21/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6951 - accuracy: 0.4839
# Epoch 21: val_loss improved from 0.69465 to 0.69462, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6951 - accuracy: 0.4829 - val_loss: 0.6946 - val_accuracy: 0.4744
# Epoch 22/30
# 17/17 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.4834
# Epoch 22: val_loss improved from 0.69462 to 0.69459, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6950 - accuracy: 0.4834 - val_loss: 0.6946 - val_accuracy: 0.4704
# Epoch 23/30
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6949 - accuracy: 0.4849
# Epoch 23: val_loss improved from 0.69459 to 0.69456, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6950 - accuracy: 0.4839 - val_loss: 0.6946 - val_accuracy: 0.4690
# Epoch 24/30
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6950 - accuracy: 0.4819
# Epoch 24: val_loss improved from 0.69456 to 0.69453, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6949 - accuracy: 0.4829 - val_loss: 0.6945 - val_accuracy: 0.4636
# Epoch 25/30
# 12/17 [====================>.........] - ETA: 0s - loss: 0.6952 - accuracy: 0.4818
# Epoch 25: val_loss improved from 0.69453 to 0.69451, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6949 - accuracy: 0.4839 - val_loss: 0.6945 - val_accuracy: 0.4663
# Epoch 26/30
#  9/17 [==============>...............] - ETA: 0s - loss: 0.6951 - accuracy: 0.4809
# Epoch 26: val_loss improved from 0.69451 to 0.69449, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6948 - accuracy: 0.4843 - val_loss: 0.6945 - val_accuracy: 0.4663
# Epoch 27/30
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6949 - accuracy: 0.4802
# Epoch 27: val_loss improved from 0.69449 to 0.69446, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 80ms/step - loss: 0.6948 - accuracy: 0.4858 - val_loss: 0.6945 - val_accuracy: 0.4690
# Epoch 28/30
# 14/17 [=======================>......] - ETA: 0s - loss: 0.6946 - accuracy: 0.4844
# Epoch 28: val_loss improved from 0.69446 to 0.69444, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 78ms/step - loss: 0.6947 - accuracy: 0.4839 - val_loss: 0.6944 - val_accuracy: 0.4717
# Epoch 29/30
# 11/17 [==================>...........] - ETA: 0s - loss: 0.6942 - accuracy: 0.4893
# Epoch 29: val_loss improved from 0.69444 to 0.69442, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 88ms/step - loss: 0.6947 - accuracy: 0.4834 - val_loss: 0.6944 - val_accuracy: 0.4704
# Epoch 30/30
# 13/17 [=====================>........] - ETA: 0s - loss: 0.6948 - accuracy: 0.4772
# Epoch 30: val_loss improved from 0.69442 to 0.69439, saving model to Models/model_binary_20.h5
# 17/17 [==============================] - 1s 80ms/step - loss: 0.6946 - accuracy: 0.4810 - val_loss: 0.6944 - val_accuracy: 0.4677

# %%
# Uncomment to load the saved models

# models=[]
# models_path = "Models"
# for f in os.listdir(models_path):
#     models.append(load_model(os.path.join(models_path, f)))

# %%
# Returns f1_scores of all the models 
def calc_f1(models, x_val, y_val):
    f1_scores = []
    for i, model in enumerate(models):
        f1_scores.append(f1_score((model.predict(x_val)>0.5).astype(int), y_val[:,i]))

    return f1_scores

# %%
f1_scores = calc_f1(models, valid_data, valid_label)

# %%
f1_scores
# Out:
# [0.4389157985238512,
#  0.3939857923520334,
#  0.1070811744386874,
#  0.10225563909774436,
#  0.4611590628853268,
#  0.11057692307692307,
#  0.1301775147928994,
#  0.5823985729572054,
#  0.002600780234070221,
#  0.21063394683026587,
#  0.1663442940038685,
#  0.3870693321990642,
#  0.06134969325153375,
#  0.12288786482334871,
#  0.4673216574113627,
#  0.2229580239523595,
#  0.5052192066805846,
#  0.1271745650869826,
#  0.20869565217391303,
#  0.2978494623655914]

# %%
np.mean(f1_scores)
# Out:
# 0.2553327478568808

# %%
# Returns accuracy of all the models
def calc_acc(models, x_val, y_val):
    acc = []
    for i, model in enumerate(models):
        acc.append(model.evaluate(x_val, y_val[:,i])[1])
    return acc, np.mean(acc)

# %%
accs, avg = calc_acc(models, valid_data, valid_label)
# Out:
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6269 - accuracy: 0.8661
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6709 - accuracy: 0.7344
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6964 - accuracy: 0.4583
# 60/60 [==============================] - 1s 4ms/step - loss: 0.8195 - accuracy: 0.0562
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7172 - accuracy: 0.3063
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6736 - accuracy: 0.7979
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7309 - accuracy: 0.0688
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6316 - accuracy: 0.9307
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6857 - accuracy: 0.5927
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6898 - accuracy: 0.5917
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7837 - accuracy: 0.0911
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7222 - accuracy: 0.2417
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7499 - accuracy: 0.0312
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7263 - accuracy: 0.0953
# 60/60 [==============================] - 1s 5ms/step - loss: 0.7008 - accuracy: 0.3396
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6043 - accuracy: 0.8547
# 60/60 [==============================] - 1s 4ms/step - loss: 0.6940 - accuracy: 0.4984
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7022 - accuracy: 0.2406
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7256 - accuracy: 0.1375
# 60/60 [==============================] - 1s 4ms/step - loss: 0.7040 - accuracy: 0.3167

# %%
avg
# Out:
# 0.41249999925494196
